# %%
# !python /workspace/mmsegmentation/tools/analysis_tools/analyze_logs.py /out/20250504_100920/vis_data/scalars.json --keys mIoU mAcc aAcc --legend mIoU mAcc aAcc --out ./results.jpg
# Out:
# plot curve of /out/20250504_100920/vis_data/scalars.json, metric is mIoU
# plot curve of /out/20250504_100920/vis_data/scalars.json, metric is mAcc
# plot curve of /out/20250504_100920/vis_data/scalars.json, metric is aAcc
# save curve to: ./results.jpg

# %%
from IPython.display import Image

# %%
Image("results.jpg")

# %%
# !python /workspace/mmsegmentation/tools/analysis_tools/analyze_logs.py /out/20250504_100920/vis_data/scalars.json --keys lr --out ./lr.jpg --legend lr
# Out:
# plot curve of /out/20250504_100920/vis_data/scalars.json, metric is lr
# save curve to: ./lr.jpg

# %%
Image("lr.jpg")
